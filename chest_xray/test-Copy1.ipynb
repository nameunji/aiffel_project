# %% [markdown]
# # 폐렴 진단
#
# data : https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia
# - 폐렴 : x-ray 사진상, 다양한 양상의 음영(폐 부위에 희미한 그림자) 증가가 관찰됨

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# # 1. set up

# %%
import re
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록 하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')

# BATCH_SIZE 변수
BATCH_SIZE = 16

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
EPOCHS = 25

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# # 2. 데이터 로드

# %%
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*'))

print(len(train_filenames), len(test_filenames), len(val_filenames))
# Out:
# 5216 624 16

# %% [markdown]
# - **validation data 갯수가 너무 부족하여 train과 val을 합쳐 80:20으로 나누기**

# %%
filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*')))
print(len(filenames))
# Out:
# 5232

# %%
# train, test(val) dataset으로 분할. test_size에 0.2는 20%롤 의미함.
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)
print(len(train_filenames), len(val_filenames))
# Out:
# 4185 1047

# %% [markdown]
# - **train data 안에 정상, 폐렴 이미지 수 체크**

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1092
# Pneumonia images count in training set: 3093

# %% [markdown]
# - **tf.data 인스턴스 생성**

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
# - **라벨 확인**

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1] 
                       for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])

print(CLASS_NAMES)
# Out:
# ['NORMAL' 'PNEUMONIA']

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# # 3. 데이터 전처리

# %% [markdown]
# - **라벨이 이미지이름에만 있기 때문에 라벨을 붙여주는 함수**

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    print(parts)
    return parts[-2] == "PNEUMONIA"  # 폐렴이면 양성(True), 노멀이면 음성(False)을 리턴

# %% [markdown]
# - **이미지 사이즈 통일 및 축소 함수**

# %%
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)  # img를 unit8 tensor로 변경
    img = tf.image.convert_image_dtype(img, tf.float32)  # img를 범위 [0,1]의 float32 타입으로 변경
    return tf.image.resize(img, IMAGE_SIZE)  # 이미지 사이즈 변경 IMAGE_SIZE = [180, 180]

# %% [markdown]
# - **이미지 path로 라벨, 사이즈 처리**

# %%
def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %% [markdown]
# - **train, validation 데이터셋 만들기**

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
# Out:
# Tensor("StringSplit/RaggedGetItem/strided_slice_5:0", shape=(None,), dtype=string)
# Tensor("StringSplit/RaggedGetItem/strided_slice_5:0", shape=(None,), dtype=string)

# %%
for image, label in train_ds.take(1):
    print("Image shape : ", image.numpy().shape)
    print("Lable : ", label.numpy())
# Out:
# Image shape :  (180, 180, 3)
# Lable :  False

# %% [markdown]
# - **test 데이터셋 처리**

# %%
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)
print(TEST_IMAGE_COUNT)
# Out:
# Tensor("StringSplit/RaggedGetItem/strided_slice_5:0", shape=(None,), dtype=string)
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# - **데이터 시각화**

# %%
# train에 있는 batch 중 첫번째 배치 추출하여 image와 label로 나눔
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# # 4. 모델 설계
# CNN

# %%
# Convolution block
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    return block

# Dense block
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    return model

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# # 5. Weight balancing
# 특정 라벨이 너무 많아 데이터의 밸런스가 맞지 않은 경우(imbalance) Weight balancing을 사용할 수 있다. Weight balancing은 training set 의 각 데이터에서 loss 를 계산할 때 특정 클래스의 데이터에 더 큰 loss 값을 갖도록 가중치를 부여하는 방법이다.

# %%
weight_for_0 = (1/COUNT_NORMAL) * (TRAIN_IMG_COUNT)/2.0
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0
class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.92
# Weight for class 1: 0.68

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# # 6. 모델 훈련

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 26s 99ms/step - loss: 0.3955 - accuracy: 0.8182 - precision: 0.9497 - recall: 0.7962 - val_loss: 0.5850 - val_accuracy: 0.7548 - val_precision: 0.7548 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 23s 86ms/step - loss: 0.2347 - accuracy: 0.9124 - precision: 0.9752 - recall: 0.9045 - val_loss: 0.9676 - val_accuracy: 0.7529 - val_precision: 0.7529 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.2101 - accuracy: 0.9148 - precision: 0.9746 - recall: 0.9083 - val_loss: 0.1106 - val_accuracy: 0.9558 - val_precision: 0.9512 - val_recall: 0.9924
# Epoch 4/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1890 - accuracy: 0.9279 - precision: 0.9751 - recall: 0.9261 - val_loss: 0.1091 - val_accuracy: 0.9567 - val_precision: 0.9501 - val_recall: 0.9949
# Epoch 5/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1717 - accuracy: 0.9344 - precision: 0.9766 - recall: 0.9336 - val_loss: 0.1845 - val_accuracy: 0.9221 - val_precision: 0.9972 - val_recall: 0.8991
# Epoch 6/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1436 - accuracy: 0.9459 - precision: 0.9858 - recall: 0.9405 - val_loss: 0.1061 - val_accuracy: 0.9577 - val_precision: 0.9947 - val_recall: 0.9490
# Epoch 7/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1529 - accuracy: 0.9413 - precision: 0.9830 - recall: 0.9367 - val_loss: 0.1828 - val_accuracy: 0.9298 - val_precision: 0.9986 - val_recall: 0.9083
# Epoch 8/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1348 - accuracy: 0.9531 - precision: 0.9862 - recall: 0.9497 - val_loss: 0.0559 - val_accuracy: 0.9817 - val_precision: 0.9923 - val_recall: 0.9834
# Epoch 9/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1339 - accuracy: 0.9495 - precision: 0.9852 - recall: 0.9459 - val_loss: 0.0899 - val_accuracy: 0.9654 - val_precision: 0.9960 - val_recall: 0.9580
# Epoch 10/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1152 - accuracy: 0.9557 - precision: 0.9889 - recall: 0.9507 - val_loss: 0.0819 - val_accuracy: 0.9712 - val_precision: 0.9772 - val_recall: 0.9847
# Epoch 11/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1093 - accuracy: 0.9595 - precision: 0.9886 - recall: 0.9563 - val_loss: 0.0718 - val_accuracy: 0.9721 - val_precision: 0.9834 - val_recall: 0.9797
# Epoch 12/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1102 - accuracy: 0.9595 - precision: 0.9863 - recall: 0.9585 - val_loss: 0.1267 - val_accuracy: 0.9529 - val_precision: 0.9973 - val_recall: 0.9401
# Epoch 13/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1195 - accuracy: 0.9504 - precision: 0.9871 - recall: 0.9452 - val_loss: 0.0455 - val_accuracy: 0.9846 - val_precision: 0.9898 - val_recall: 0.9898
# Epoch 14/25
# 261/261 [==============================] - 23s 86ms/step - loss: 0.1027 - accuracy: 0.9650 - precision: 0.9913 - recall: 0.9610 - val_loss: 0.1487 - val_accuracy: 0.9500 - val_precision: 0.9986 - val_recall: 0.9349
# Epoch 15/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.0995 - accuracy: 0.9638 - precision: 0.9910 - recall: 0.9599 - val_loss: 0.2807 - val_accuracy: 0.8923 - val_precision: 1.0000 - val_recall: 0.8575
# Epoch 16/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1052 - accuracy: 0.9605 - precision: 0.9896 - recall: 0.9566 - val_loss: 0.5841 - val_accuracy: 0.8365 - val_precision: 1.0000 - val_recall: 0.7832
# Epoch 17/25
# 261/261 [==============================] - 24s 90ms/step - loss: 0.0930 - accuracy: 0.9641 - precision: 0.9916 - recall: 0.9596 - val_loss: 0.0592 - val_accuracy: 0.9788 - val_precision: 0.9987 - val_recall: 0.9732
# Epoch 18/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0759 - accuracy: 0.9725 - precision: 0.9950 - recall: 0.9675 - val_loss: 0.1698 - val_accuracy: 0.9279 - val_precision: 0.9986 - val_recall: 0.9056
# Epoch 19/25
# 261/261 [==============================] - 23s 86ms/step - loss: 0.0703 - accuracy: 0.9758 - precision: 0.9950 - recall: 0.9721 - val_loss: 0.0521 - val_accuracy: 0.9817 - val_precision: 0.9885 - val_recall: 0.9873
# Epoch 20/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0974 - accuracy: 0.9607 - precision: 0.9903 - recall: 0.9564 - val_loss: 0.0941 - val_accuracy: 0.9635 - val_precision: 0.9783 - val_recall: 0.9733
# Epoch 21/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0833 - accuracy: 0.9679 - precision: 0.9910 - recall: 0.9652 - val_loss: 0.0444 - val_accuracy: 0.9856 - val_precision: 0.9898 - val_recall: 0.9911
# Epoch 22/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0697 - accuracy: 0.9727 - precision: 0.9937 - recall: 0.9693 - val_loss: 0.0534 - val_accuracy: 0.9846 - val_precision: 0.9848 - val_recall: 0.9949
# Epoch 23/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.0723 - accuracy: 0.9739 - precision: 0.9943 - recall: 0.9701 - val_loss: 0.0781 - val_accuracy: 0.9712 - val_precision: 0.9948 - val_recall: 0.9669
# Epoch 24/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.0844 - accuracy: 0.9684 - precision: 0.9927 - recall: 0.9645 - val_loss: 0.0553 - val_accuracy: 0.9827 - val_precision: 0.9836 - val_recall: 0.9936
# Epoch 25/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0688 - accuracy: 0.9758 - precision: 0.9950 - recall: 0.9721 - val_loss: 0.0982 - val_accuracy: 0.9769 - val_precision: 0.9727 - val_recall: 0.9975

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# # 7. 결과

# %% [markdown]
# - **epoch마다 모델의 precision, recall, accuracy, loss이 어떻게 변하는지 그래프 출력**

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# - **test 데이터로 모델 평가**

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 2s 61ms/step - loss: 1.7010 - accuracy: 0.7212 - precision: 0.6915 - recall: 1.0000
